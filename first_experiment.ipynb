# %%
from huggingface_hub import login

login(token="")

# %%
import time, torch, numpy as np, pandas as pd
from tqdm import trange
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)

# ----------------------------------------------------------
# CONFIG
# ----------------------------------------------------------
MODEL_NAME = "meta-llama/Llama-3.2-3B"
NUM_RUNS = 1000
MAX_NEW_TOKENS = 32
PROMPT = "Explain one interesting fact about large language models."

# ----------------------------------------------------------
# DEVICE
# ----------------------------------------------------------
if torch.backends.mps.is_available():
    DEVICE = "mps"  # MacBook M3
elif torch.cuda.is_available():
    DEVICE = "cuda"  # GPU cluster (A100/H100)
else:
    DEVICE = "cpu"

print(f"Running on device: {DEVICE}")

# ----------------------------------------------------------
# PRECISIONS TO TEST
# ----------------------------------------------------------
precisions = ["fp16", "int4"]

# ----------------------------------------------------------
# UTILITIES
# ----------------------------------------------------------
def setup_model(precision):
    fp16_model = "meta-llama/Llama-3.2-3B"
    awq_int4_model = "casperhansen/llama-3.2-3b-instruct-awq"  # already quantized

    if precision == "fp16":
        print("Loading FP16 model...")
        model = AutoModelForCausalLM.from_pretrained(
            fp16_model,
            dtype=torch.float16,
            device_map="auto"
        )
        model.to(DEVICE)

    elif precision == "int4":
        if not torch.cuda.is_available():
            print("Skipping INT4 (requires CUDA).")
            return None

        print("Loading INT4 AWQ model...")
        model = AutoModelForCausalLM.from_pretrained(
            "casperhansen/llama-3.2-3b-instruct-awq", 
            device_map="auto",
            trust_remote_code=True)

    else:
        raise ValueError(f"Unknown precision mode: {precision}")

    return model


def clear_cache():
    if DEVICE == "cuda":
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats()
    elif DEVICE == "mps":
        torch.mps.empty_cache()
    else:
        pass


def get_mem_mb():
    if DEVICE == "cuda":
        return torch.cuda.memory_allocated() / (1024**2)
    else:
        return 0.0  # MPS/CPU memory metrics not available in PyTorch


@torch.no_grad()
def benchmark_model(model, tokenizer):
    latencies, peak_mems, avg_mems = [], [], []
    for i in trange(NUM_RUNS):
        clear_cache()
        inputs = tokenizer(PROMPT, return_tensors="pt").to(DEVICE)
        start = time.time()
        _ = model.generate(**inputs, max_new_tokens=MAX_NEW_TOKENS)
        if DEVICE == "cuda":
            torch.cuda.synchronize()
        end = time.time()

        latency = end - start
        peak_mem = torch.cuda.max_memory_allocated() / (1024 ** 2) if DEVICE == "cuda" else 0.0
        avg_mem = get_mem_mb()

        latencies.append(latency)
        peak_mems.append(peak_mem)
        avg_mems.append(avg_mem)

    lat = np.array(latencies)
    pm = np.array(peak_mems)
    am = np.array(avg_mems)

    results = {
        "precision": precision,
        "mean_latency_s": lat.mean(),
        "median_latency_s": np.median(lat),
        "p95_latency_s": np.percentile(lat, 95),
        "p99_latency_s": np.percentile(lat, 99),
        "mean_peak_mem_mb": pm.mean(),
        "mean_avg_mem_mb": am.mean(),
    }
    return results
# Out:
# Running on device: cuda

# %%
# ----------------------------------------------------------
# MAIN
# ----------------------------------------------------------
import os

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

all_results = []
csv_path = "llama3.2_all_precisions_latency_memory.csv"

if not os.path.exists(csv_path):
    pd.DataFrame(columns=[
        "precision", "mean_latency", "median_latency", "p95_latency", "p99_latency",
        "peak_memory_mb", "avg_memory_mb"
    ]).to_csv(csv_path, index=False)


for precision in precisions:
    model = setup_model(precision)
    if model is None:
        continue  # skip INT8/INT4 on Mac
    model.eval()
    print(f"\n=== Running benchmark: {precision.upper()} ===")
    results = benchmark_model(model, tokenizer)
    all_results.append(results)

    pd.DataFrame([results]).to_csv(csv_path, mode='a', header=False, index=False)

    print(f"\n--- {precision.upper()} Summary ---")
    for k, v in results.items():
        if k != "precision":
            print(f"{k}: {v:.4f}")
    print(f"Results written to {csv_path}\n")

    del model
    clear_cache()

# ----------------------------------------------------------
# OUTPUT
# ----------------------------------------------------------
if all_results:
    df = pd.DataFrame(all_results)
    print("\n===== SUMMARY =====")
    print(df.round(3))
    df.to_csv("llama3.2_all_precisions_latency_memory.csv", index=False)
    print("\nResults saved to llama3.2_all_precisions_latency_memory.csv")
else:
    print("No models ran (probably running on Mac without CUDA).")
# Out:
# Loading FP16 model...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# === Running benchmark: FP16 ===
#   0%|          | 0/1000 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 1/1000 [00:00<13:04,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 2/1000 [00:01<13:02,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 3/1000 [00:02<13:01,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 4/1000 [00:03<13:00,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 5/1000 [00:03<12:59,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 6/1000 [00:04<12:58,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 7/1000 [00:05<12:59,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 8/1000 [00:06<12:57,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 9/1000 [00:07<12:53,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 10/1000 [00:07<12:47,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 11/1000 [00:08<12:42,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 12/1000 [00:09<12:39,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 13/1000 [00:10<12:36,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 14/1000 [00:10<12:34,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 15/1000 [00:11<12:35,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 16/1000 [00:12<12:39,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 17/1000 [00:13<12:33,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 18/1000 [00:13<12:33,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 19/1000 [00:14<12:38,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 20/1000 [00:15<12:41,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 21/1000 [00:16<12:51,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 22/1000 [00:17<12:48,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 23/1000 [00:17<12:51,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 24/1000 [00:18<12:50,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▎         | 25/1000 [00:19<12:46,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 26/1000 [00:20<12:44,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 27/1000 [00:21<12:43,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 28/1000 [00:21<12:41,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 29/1000 [00:22<12:40,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 30/1000 [00:23<12:39,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 31/1000 [00:24<12:37,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 32/1000 [00:24<12:37,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 33/1000 [00:25<12:37,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 34/1000 [00:26<12:35,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 35/1000 [00:27<12:34,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 36/1000 [00:28<12:33,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 37/1000 [00:28<12:32,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 38/1000 [00:29<12:32,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 39/1000 [00:30<12:31,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 40/1000 [00:31<12:30,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 41/1000 [00:31<12:29,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 42/1000 [00:32<12:28,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 43/1000 [00:33<12:28,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 44/1000 [00:34<12:26,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 45/1000 [00:35<12:24,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 46/1000 [00:35<12:25,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 47/1000 [00:36<12:22,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 48/1000 [00:37<12:19,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 49/1000 [00:38<12:18,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 50/1000 [00:38<12:19,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 51/1000 [00:39<12:24,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 52/1000 [00:40<12:22,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 53/1000 [00:41<12:17,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 54/1000 [00:42<12:17,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 55/1000 [00:42<12:17,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 56/1000 [00:43<12:17,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 57/1000 [00:44<12:15,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 58/1000 [00:45<12:14,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 59/1000 [00:46<12:11,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 60/1000 [00:46<10:02,  1.56it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 61/1000 [00:47<10:39,  1.47it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 62/1000 [00:47<11:05,  1.41it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 63/1000 [00:48<11:24,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 64/1000 [00:49<11:38,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 65/1000 [00:50<11:46,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         |
  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 932/1000 [21:21<01:33,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 933/1000 [21:22<01:31,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 934/1000 [21:23<01:30,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 935/1000 [21:25<01:29,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 936/1000 [21:26<01:29,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 937/1000 [21:28<01:28,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 938/1000 [21:29<01:26,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 939/1000 [21:30<01:24,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 940/1000 [21:32<01:22,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 941/1000 [21:33<01:21,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 942/1000 [21:34<01:19,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 943/1000 [21:36<01:18,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 944/1000 [21:37<01:17,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 945/1000 [21:39<01:16,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 946/1000 [21:40<01:15,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 947/1000 [21:41<01:13,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 948/1000 [21:43<01:11,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 949/1000 [21:44<01:10,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 950/1000 [21:46<01:08,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 951/1000 [21:47<01:07,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 952/1000 [21:48<01:05,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 953/1000 [21:50<01:04,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 954/1000 [21:51<01:03,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 955/1000 [21:52<01:01,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 956/1000 [21:54<01:00,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 957/1000 [21:55<00:59,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 958/1000 [21:57<00:57,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 959/1000 [21:58<00:56,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 960/1000 [21:59<00:54,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 961/1000 [22:01<00:53,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 962/1000 [22:02<00:52,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 963/1000 [22:03<00:50,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 964/1000 [22:05<00:49,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 965/1000 [22:06<00:47,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 966/1000 [22:08<00:46,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 967/1000 [22:09<00:45,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 968/1000 [22:10<00:44,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 969/1000 [22:12<00:43,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 970/1000 [22:13<00:42,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 971/1000 [22:15<00:40,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 972/1000 [22:16<00:38,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 973/1000 [22:17<00:37,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 974/1000 [22:19<00:35,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 975/1000 [22:20<00:34,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 976/1000 [22:21<00:32,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 977/1000 [22:23<00:31,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 978/1000 [22:24<00:30,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 979/1000 [22:25<00:28,  1.36s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 980/1000 [22:27<00:27,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 981/1000 [22:28<00:25,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 982/1000 [22:30<00:24,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 983/1000 [22:31<00:23,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 984/1000 [22:32<00:21,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 985/1000 [22:34<00:20,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 986/1000 [22:35<00:19,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 987/1000 [22:36<00:17,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 988/1000 [22:38<00:16,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 989/1000 [22:39<00:15,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 990/1000 [22:41<00:13,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 991/1000 [22:42<00:12,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 992/1000 [22:43<00:11,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 993/1000 [22:45<00:09,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 994/1000 [22:46<00:08,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 995/1000 [22:47<00:06,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 996/1000 [22:49<00:05,  1.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 997/1000 [22:50<00:04,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 998/1000 [22:52<00:02,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 999/1000 [22:53<00:01,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 1000/1000 [22:54<00:00,  1.37s/it]
# --- INT4 Summary ---
# mean_latency_s: 1.3712
# median_latency_s: 1.3650
# p95_latency_s: 1.4143
# p99_latency_s: 1.4340
# mean_peak_mem_mb: 8310.7285
# mean_avg_mem_mb: 8299.9639
# Results written to llama3.2_all_precisions_latency_memory.csv
#
#
# ===== SUMMARY =====
#   precision  mean_latency_s  median_latency_s  p95_latency_s  p99_latency_s  \
# 0      fp16           0.764             0.771          0.810          0.817
# 1      int4           1.371             1.365          1.414          1.434
#
#    mean_peak_mem_mb  mean_avg_mem_mb
# 0         12280.174        12269.464
# 1          8310.729         8299.964
#
# Results saved to llama3.2_all_precisions_latency_memory.csv

# %%
model.save_pretrained("llama3.2-3B-local")
tokenizer.save_pretrained("llama3.2-3B-local")
# Out:
# ('llama3.2-3B-local/tokenizer_config.json',
#  'llama3.2-3B-local/special_tokens_map.json',
#  'llama3.2-3B-local/tokenizer.json')
